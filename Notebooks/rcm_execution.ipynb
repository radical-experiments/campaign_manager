# %%
import radical.utils as ru
import radical.analytics as ra
import pandas as pd
from glob import glob

from matplotlib import pyplot as plt
from matplotlib import cm
import numpy as np
#import matplotlib as mpl
#mpl.rcParams['text.usetex'] = True
#mpl.rcParams['text.latex.unicode'] = True

blues = cm.get_cmap(plt.get_cmap('Blues'))
greens = cm.get_cmap(plt.get_cmap('Greens'))
reds = cm.get_cmap(plt.get_cmap('Reds'))
oranges = cm.get_cmap(plt.get_cmap('Oranges'))
purples = cm.get_cmap(plt.get_cmap('Purples'))
greys = cm.get_cmap(plt.get_cmap('Greys'))
set1 = cm.get_cmap(plt.get_cmap('Set1'))
tab20 = cm.get_cmap(plt.get_cmap('tab20'))

def tableau20(color):
    # Use coordinated colors. These are the "Tableau 20" colors as
    # RGB. Each pair is strong/light. For a theory of color
    tableau20 = [(31 , 119, 180), (174, 199, 232), # blue        [ 0,1 ]
                 (255, 127, 14 ), (255, 187, 120), # orange      [ 2,3 ]
                 (44 , 160, 44 ), (152, 223, 138), # green       [ 4,5 ]
                 (214, 39 , 40 ), (255, 152, 150), # red         [ 6,7 ]
                 (148, 103, 189), (197, 176, 213), # purple      [ 8,9 ]
                 (140, 86 , 75 ), (196, 156, 148), # brown       [10,11]
                 (227, 119, 194), (247, 182, 210), # pink        [12,13]
                 (188, 189, 34 ), (219, 219, 141), # yellow      [14,15]
                 (23 , 190, 207), (158, 218, 229), # cyan        [16,17]
                 (65 , 68 , 81 ), (96 , 99 , 106), # gray        [18,19]
                 (127, 127, 127), (143, 135, 130), # gray        [20,21]
                 (165, 172, 175), (199, 199, 199), # gray        [22,23]
                 (207, 207, 207)]                   # gray        [24]
    # Scale the RGB values to the [0, 1] range, which is the format
    # matplotlib accepts.
    r, g, b = tableau20[color]
    return (round(r/255.,1), round(g/255.,1), round(b/255.,1))

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
work4res4 = glob('../Data/rcm/4res/4work4res/rcm*')
work8res4 = glob('../Data/rcm/4res/8work4res/rcm*')
work16res4 = glob('../Data/rcm/4res/16work4res/rcm*')
work32res4 = glob('../Data/rcm/4res/32work4res/rcm*')
work64res4 = glob('../Data/rcm/4res/64work4res/rcm*')
work128res4 = glob('../Data/rcm/4res/128work4res/rcm*')

bookkeeping = pd.DataFrame(columns=['workflows','execution_time', 'planning_time'])


for session in work4res4:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [4, book_end - book_start, plan_end - plan_start]

for session in work8res4:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [8, book_end - book_start, plan_end - plan_start]
    
for session in work16res4:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [16, book_end - book_start, plan_end - plan_start]
    
for session in work32res4:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [32, book_end - book_start, plan_end - plan_start]
    
for session in work64res4:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [64, book_end - book_start, plan_end - plan_start]
    
for session in work128res4:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [128, book_end - book_start, plan_end - plan_start]
    
res4 = bookkeeping.groupby('workflows')
res4_means = res4.mean()
res4_stds = res4.std()

# %%
work4res8 = glob('../Data/rcm/8res/4work8res/rcm*')
work8res8 = glob('../Data/rcm/8res/8work8res/rcm*')
work16res8 = glob('../Data/rcm/8res/16work8res/rcm*')
work32res8 = glob('../Data/rcm/8res/32work8res/rcm*')
work64res8 = glob('../Data/rcm/8res/64work8res/rcm*')
work128res8 = glob('../Data/rcm/8res/128work8res/rcm*')

bookkeeping = pd.DataFrame(columns=['workflows','execution_time', 'planning_time'])


for session in work4res8:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [4, book_end - book_start, plan_end - plan_start]

for session in work8res8:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [8, book_end - book_start, plan_end - plan_start]
    
for session in work16res8:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [16, book_end - book_start, plan_end - plan_start]
    
for session in work32res8:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [32, book_end - book_start, plan_end - plan_start]
    
for session in work64res8:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [64, book_end - book_start, plan_end - plan_start]
    
for session in work128res8:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [128, book_end - book_start, plan_end - plan_start]
    
res8 = bookkeeping.groupby('workflows')
res8_means = res8.mean()
res8_stds = res8.std()

# %%
work4res16 = glob('../Data/rcm/16res/4work16res/rcm*')
work8res16 = glob('../Data/rcm/16res/8work16res/rcm*')
work16res16 = glob('../Data/rcm/16res/16work16res/rcm*')
work32res16 = glob('../Data/rcm/16res/32work16res/rcm*')
work64res16 = glob('../Data/rcm/16res/64work16res/rcm*')
work128res16 = glob('../Data/rcm/16res/128work16res/rcm*')

bookkeeping = pd.DataFrame(columns=['workflows','execution_time', 'planning_time'])


for session in work4res16:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [4, book_end - book_start, plan_end - plan_start]

for session in work8res16:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [8, book_end - book_start, plan_end - plan_start]
    
for session in work16res16:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [16, book_end - book_start, plan_end - plan_start]
    
for session in work32res16:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [32, book_end - book_start, plan_end - plan_start]
    
for session in work64res16:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [64, book_end - book_start, plan_end - plan_start]
    
for session in work128res16:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [128, book_end - book_start, plan_end - plan_start]
    
res16 = bookkeeping.groupby('workflows')
res16_means = res16.mean()
res16_stds = res16.std()

# %%
work4res32 = glob('../Data/rcm/32res/4work32res/rcm*')
work8res32 = glob('../Data/rcm/32res/8work32res/rcm*')
work16res32 = glob('../Data/rcm/32res/16work32res/rcm*')
work32res32 = glob('../Data/rcm/32res/32work32res/rcm*')
work64res32 = glob('../Data/rcm/32res/64work32res/rcm*')
work128res32 = glob('../Data/rcm/32res/128work32res/rcm*')

bookkeeping = pd.DataFrame(columns=['workflows','execution_time', 'planning_time'])


for session in work4res32:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [4, book_end - book_start, plan_end - plan_start]

for session in work8res32:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [8, book_end - book_start, plan_end - plan_start]
    
for session in work16res32:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [16, book_end - book_start, plan_end - plan_start]
    
for session in work32res32:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [32, book_end - book_start, plan_end - plan_start]
    
for session in work64res32:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [64, book_end - book_start, plan_end - plan_start]
    
for session in work128res32:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [128, book_end - book_start, plan_end - plan_start]
    
res32 = bookkeeping.groupby('workflows')
res32_means = res32.mean()
res32_stds = res32.std()

# %%
work4res64 = glob('../Data/rcm/64res/4work64res/rcm*')
work8res64 = glob('../Data/rcm/64res/8work64res/rcm*')
work16res64 = glob('../Data/rcm/64res/16work64res/rcm*')
work32res64 = glob('../Data/rcm/64res/32work64res/rcm*')
work64res64 = glob('../Data/rcm/64res/64work64res/rcm*')
work128res64 = glob('../Data/rcm/64res/128work64res/rcm*')

bookkeeping = pd.DataFrame(columns=['workflows','execution_time', 'planning_time'])


for session in work4res64:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [4, book_end - book_start, plan_end - plan_start]

for session in work8res64:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [8, book_end - book_start, plan_end - plan_start]
    
for session in work16res64:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [16, book_end - book_start, plan_end - plan_start]
    
for session in work32res64:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [32, book_end - book_start, plan_end - plan_start]
    
for session in work64res64:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [64, book_end - book_start, plan_end - plan_start]
    
for session in work128res64:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [128, book_end - book_start, plan_end - plan_start]
    
res64 = bookkeeping.groupby('workflows')
res64_means = res64.mean()
res64_stds = res64.std()

# %%
work4res128 = glob('../Data/rcm/128res/4work128res/rcm*')
work8res128 = glob('../Data/rcm/128res/8work128res/rcm*')
work16res128 = glob('../Data/rcm/128res/16work128res/rcm*')
work32res128 = glob('../Data/rcm/128res/32work128res/rcm*')
work64res128 = glob('../Data/rcm/128res/64work128res/rcm*')
work128res128 = glob('../Data/rcm/128res/128work128res/rcm*')

bookkeeping = pd.DataFrame(columns=['workflows','execution_time', 'planning_time'])


for session in work4res128:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [4, book_end - book_start, plan_end - plan_start]

for session in work8res128:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [8, book_end - book_start, plan_end - plan_start]
    
for session in work16res128:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [16, book_end - book_start, plan_end - plan_start]
    
for session in work32res128:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [32, book_end - book_start, plan_end - plan_start]
    
for session in work64res128:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [64, book_end - book_start, plan_end - plan_start]
    
for session in work128res128:
    bookkeeping_prof = open(session+'/bookkeper.0000.prof')
    prof_lines = bookkeeping_prof.readlines()
    for line in prof_lines:
        if 'bookkeper_start' in line:
            book_start = eval(line.split(',')[0])
        elif 'bookkeper_stopping' in line:
            book_end = eval(line.split(',')[0])
        elif 'planning_start' in line:
            plan_start = eval(line.split(',')[0])
        elif 'planning_ended' in line:
            plan_end = eval(line.split(',')[0])
    bookkeeping_prof.close()
    bookkeeping.loc[len(bookkeeping)] = [128, book_end - book_start, plan_end - plan_start]
    
res128 = bookkeeping.groupby('workflows')
res128_means = res128.mean()
res128_stds = res128.std()

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(res4_means.index,res4_means['execution_time'].values, yerr=res4_stds['execution_time'].values / np.sqrt(10), color=tableau20(2), label='$N_R=4$')
_ = axis.errorbar(res8_means.index,res8_means['execution_time'].values, yerr=res8_stds['execution_time'].values / np.sqrt(10), color=tableau20(4), label='$N_R=8$')
_ = axis.errorbar(res16_means.index,res16_means['execution_time'].values, yerr=res16_stds['execution_time'].values / np.sqrt(10), color=tableau20(6), label='$N_R=16$')
_ = axis.errorbar(res32_means.index,res32_means['execution_time'].values, yerr=res32_stds['execution_time'].values / np.sqrt(10), color=tableau20(8), label='$N_R=32$')
_ = axis.errorbar(res64_means.index,res64_means['execution_time'].values, yerr=res64_stds['execution_time'].values / np.sqrt(10), color=tableau20(10), label='$N_R=64$')
_ = axis.errorbar(res128_means.index,res128_means['execution_time'].values, yerr=res128_stds['execution_time'].values / np.sqrt(10), color=tableau20(12), label='$N_R=128$')

# _ = axis.fill_between(workflows_sizes, min_vals, max_vals, color=greens(250), alpha=0.2, label='RANDOM Max-Min')
#_ = axis.set_yscale('log')
#_ = axis.set_xscale('symlog',basex=2)
_ = axis.set_ylabel('Execution time in seconds',fontsize=20)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
_ = axis.set_xticks(res4_means.index)
_ = axis.set_xticklabels(axis.get_xticks().astype('int'),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()).astype('float').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
#_ = axis.set_title('As a function of the number of resources', fontsize=22)
_ = axis.legend(fontsize=20)
_ = fig.savefig('../Figures/SimTimeWork.pdf',bbox_inches='tight')
_ = fig.savefig('../Figures/SimTimeWork.png',bbox_inches='tight')

# %%
res64_means
# Out:
#            execution_time  planning_time
# workflows
# 4.0              3.305901       0.000925
# 8.0              7.670265       0.001060
# 16.0            14.452185       0.002068
# 32.0            30.753819       0.004065
# 64.0            65.552979       0.005286
# 128.0          179.523265       0.017462

# %%
res128_means
# Out:
#            execution_time  planning_time
# workflows
# 4.0              3.413760       0.001024
# 8.0              7.415917       0.001381
# 16.0            15.820987       0.002181
# 32.0            28.940320       0.003821
# 64.0            62.431476       0.007338
# 128.0          395.932327       0.023243
