# %%
from matplotlib import pyplot as plt
from matplotlib import cm
import pandas as pd
from pprint import pprint
from random import randint
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
#import matplotlib as mpl
#mpl.rcParams['text.usetex'] = True
#mpl.rcParams['text.latex.unicode'] = True

blues = cm.get_cmap(plt.get_cmap('Blues'))
greens = cm.get_cmap(plt.get_cmap('Greens'))
reds = cm.get_cmap(plt.get_cmap('Reds'))
oranges = cm.get_cmap(plt.get_cmap('Oranges'))
purples = cm.get_cmap(plt.get_cmap('Purples'))
greys = cm.get_cmap(plt.get_cmap('Greys'))
set1 = cm.get_cmap(plt.get_cmap('Set1'))
tab20 = cm.get_cmap(plt.get_cmap('tab20'))

def tableau20(color):
    # Use coordinated colors. These are the "Tableau 20" colors as
    # RGB. Each pair is strong/light. For a theory of color
    tableau20 = [(31 , 119, 180), (174, 199, 232), # blue        [ 0,1 ]
                 (255, 127, 14 ), (255, 187, 120), # orange      [ 2,3 ]
                 (44 , 160, 44 ), (152, 223, 138), # green       [ 4,5 ]
                 (214, 39 , 40 ), (255, 152, 150), # red         [ 6,7 ]
                 (148, 103, 189), (197, 176, 213), # purple      [ 8,9 ]
                 (140, 86 , 75 ), (196, 156, 148), # brown       [10,11]
                 (227, 119, 194), (247, 182, 210), # pink        [12,13]
                 (188, 189, 34 ), (219, 219, 141), # yellow      [14,15]
                 (23 , 190, 207), (158, 218, 229), # cyan        [16,17]
                 (65 , 68 , 81 ), (96 , 99 , 106), # gray        [18,19]
                 (127, 127, 127), (143, 135, 130), # gray        [20,21]
                 (165, 172, 175), (199, 199, 199), # gray        [22,23]
                 (207, 207, 207)]                   # gray        [24]
    # Scale the RGB values to the [0, 1] range, which is the format
    # matplotlib accepts.
    r, g, b = tableau20[color]
    return (round(r/255.,1), round(g/255.,1), round(b/255.,1))

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['expected']
StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc = pd.read_csv('../Data/heft/StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.csv')
StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc['expected']
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc.csv')
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc['expected']

StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc = StHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc = StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_90perc.groupby(by=['planner','size'])

StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['expected']
StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc = pd.read_csv('../Data/l2ff/StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.csv')
StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc['expected']
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc.csv')
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc['expected']

StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc = StHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc = StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_90perc.groupby(by=['planner','size'])

StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc = pd.read_csv('../Data/ga/perc_050/StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.csv')
StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['mpn_snt_norm'] = StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['mpn_snt'] / StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['expected']
StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc.csv')
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc['mpn_snt_norm'] = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc['mpn_snt'] / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc['expected']
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)

StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.groupby(by=['planner','size'])
StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc = StHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc = StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_90perc.groupby(by=['planner','size'])

# %%
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['expected']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['expected']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['expected']

DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['makespan']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['reactive']) / DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['makespan']

StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['makespan']


DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.groupby(by=['planner','size'])

# %%
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['expected']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['expected']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['expected']

DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['makespan']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['reactive']) / DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['makespan']

StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['makespan']


DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.groupby(by=['planner','size'])

# %%
DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['mpn_snt_norm'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['mpn_snt'] / DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['expected']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['mpn_snt_norm'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['mpn_snt'] / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['expected']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)

DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['makespan']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['gain_norm'] = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['reactive']) / DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['makespan']

StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['makespan']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['gain_norm'] = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['reactive']) / StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['makespan']


DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.groupby(by=['planner','size'])

# %%
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean()

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.std().xs('HEFT')['reactive'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.std().xs('GA-50')['reactive'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.std().xs('L2FF')['reactive'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 5% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.set_ylabel('Makespan sensitivity',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT')['mpn_snt_norm'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.std().xs('HEFT')['mpn_snt_norm'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50')['mpn_snt_norm'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.std().xs('GA-50')['mpn_snt_norm'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF')['mpn_snt_norm'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.std().xs('L2FF')['mpn_snt_norm'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.std().xs('HEFT')['reactive'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.std().xs('GA-50')['reactive'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.std().xs('L2FF')['reactive'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
#_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 5% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.std().xs('HEFT')['reactive'], marker='s',label='Reactive HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.std().xs('GA-50')['reactive'], color=tableau20(8),marker='^',label='Reactive GA-50',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='Reactive L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 5% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT')['mpn_snt_norm'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.std().xs('HEFT')['mpn_snt_norm'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50')['mpn_snt_norm'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.std().xs('GA-50')['mpn_snt_norm'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF')['mpn_snt_norm'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.std().xs('L2FF')['mpn_snt_norm'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.std().xs('HEFT')['reactive'], marker='s',label='Reactive HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.std().xs('GA-50')['reactive'], color=tableau20(8),marker='^',label='Reactive GA-50',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='Reactive L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
#_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 5% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 10% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 10% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 20% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 20% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 30% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 30% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 40% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 40% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 50% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 50% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 60% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 60% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 70% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 70% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 80% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 80% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['reactive'], marker='s',label='Reactive HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.std().xs('GA-50')['reactive'], color=tableau20(9),marker='^',label='Reactive GA-50',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='Reactive L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of workflows', fontsize=22)
#_ = fig.savefig('../Figures/InaccurStHomoCampaigns_4DynResources.png',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['mpn_snt_norm'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['mpn_snt_norm'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['mpn_snt_norm'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.std().xs('GA-50')['mpn_snt_norm'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['mpn_snt_norm'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.std().xs('L2FF')['mpn_snt_norm'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['reactive'], marker='s',label='Reactive HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.std().xs('GA-50')['reactive'], color=tableau20(9),marker='^',label='Reactive GA-50',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='Reactive L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()).astype('float').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of workflows', fontsize=22)
#_ = fig.savefig('../Figures/InaccurStHomoCampaigns_4DynResources.png',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.std().xs('HEFT')['mpn_snt_norm'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.std().xs('GA-50')['mpn_snt_norm'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.std().xs('L2FF')['mpn_snt_norm'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.std().xs('HEFT')['reactive'], marker='s',label='Reactive HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.std().xs('GA-50')['reactive'], color=tableau20(9),marker='^',label='Reactive GA-50',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='Reactive L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of resources', fontsize=22)
#_ = fig.savefig('../Figures/InaccurHeteroResources_StHomoCampaigns.png', bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['mpn_snt_norm'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.std().xs('HEFT')['mpn_snt_norm'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['mpn_snt_norm'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.std().xs('GA-50')['mpn_snt_norm'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['mpn_snt_norm'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.std().xs('L2FF')['mpn_snt_norm'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.std().xs('HEFT')['reactive'], marker='s',label='Reactive HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.std().xs('GA-50')['reactive'], color=tableau20(9),marker='^',label='Reactive GA-50',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='Reactive L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()).astype('float').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of resources', fontsize=22)
#_ = fig.savefig('../Figures/InaccurHeteroResources_StHomoCampaigns.png', bbox_inches='tight')

# %%
HEFTx = np.array([StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT').index.values.tolist()])

HEFTy = np.array([StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist()])

HEFTyStd = np.array([StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist()])

L2FFx = np.array([StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF').index.values.tolist()])

L2FFy = np.array([StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist()])

L2FFyStd = np.array([StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist()])

GA50x = np.array([StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50').index.values.tolist()])

GA50y = np.array([StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist()])

GA50yStd = np.array([StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist()])
z = np.array([[10],
     [20],
     [30],
     [40],
     [50]])

fig, axis = plt.subplots(ncols=5, nrows=1, figsize=(35,5.5), sharey=True, sharex=True)
#axis = fig.add_subplot(111, projection='3d')
_ = axis[0].errorbar(HEFTx[0], HEFTy[0], yerr=HEFTyStd[0] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[1].errorbar(HEFTx[1], HEFTy[1], yerr=HEFTyStd[1] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[2].errorbar(HEFTx[2], HEFTy[2], yerr=HEFTyStd[2] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[3].errorbar(HEFTx[3], HEFTy[3], yerr=HEFTyStd[3] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[4].errorbar(HEFTx[4], HEFTy[4], yerr=HEFTyStd[4] / 10, label='HEFT', color=tableau20(2), marker='s')

_ = axis[0].errorbar(GA50x[0], GA50y[0], yerr=GA50yStd[0] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[1].errorbar(GA50x[1], GA50y[1], yerr=GA50yStd[1] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[2].errorbar(GA50x[2], GA50y[2], yerr=GA50yStd[2] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[3].errorbar(GA50x[3], GA50y[3], yerr=GA50yStd[3] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[4].errorbar(GA50x[4], GA50y[4], yerr=GA50yStd[4] / 10, label='GA-50', color=tableau20(8), marker='s')

_ = axis[0].errorbar(L2FFx[0], L2FFy[0], yerr=L2FFyStd[0] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[1].errorbar(L2FFx[1], L2FFy[1], yerr=L2FFyStd[1] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[2].errorbar(L2FFx[2], L2FFy[2], yerr=L2FFyStd[2] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[3].errorbar(L2FFx[3], L2FFy[3], yerr=L2FFyStd[3] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[4].errorbar(L2FFx[4], L2FFy[4], yerr=L2FFyStd[4] / 10, label='L2FF', color=tableau20(10), marker='s')
#_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
#_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis[0].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[1].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[2].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[3].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[4].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
#_ = axis[2,3].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
#_ = axis[2,4].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
#_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=10)
#_ = axis[0,0].set_ylabel('HEFT Normalized Sensitivity', fontsize=16, labelpad=10)
#_ = axis[1,0].set_ylabel('GA50 Normalized Sensitivity', fontsize=16, labelpad=10)
_ = axis[0].set_ylabel('Sensitivity in percentage', fontsize=16, labelpad=10)
_ = axis[2].legend(fontsize=16, loc='lower center', ncol=3, bbox_to_anchor=(.5,-.35))
_ = axis[0].set_xscale('symlog', basex=2)
#_ = axis.set_xticks([4,8,16,32,64,128,256,1024])
#_ = axis.set_yticks([10,20,30,40,50])
_ = axis[0].grid('on')
#_ = axis[0,1].grid('on')
#_ = axis[0,2].grid('on')
#_ = axis[0,3].grid('on')
#_ = axis[0,4].grid('on')

#_ = axis[1,0].grid('on')
#_ = axis[1,1].grid('on')
#_ = axis[1,2].grid('on')
#_ = axis[1,3].grid('on')
#_ = axis[1,4].grid('on')

#_ = axis[2,0].grid('on')
#_ = axis[2,1].grid('on')
#_ = axis[2,2].grid('on')
#_ = axis[2,3].grid('on')
#_ = axis[2,4].grid('on')
_ = axis[1].grid('on')
_ = axis[2].grid('on')
_ = axis[3].grid('on')
_ = axis[4].grid('on')
_ = axis[0].set_title('10% uncertainty', fontsize=18)
_ = axis[1].set_title('20% uncertainty', fontsize=18)
_ = axis[2].set_title('30% uncertainty', fontsize=18)
_ = axis[3].set_title('40% uncertainty', fontsize=18)
_ = axis[4].set_title('50% uncertainty', fontsize=18)
#_ = axis[0,3].set_title('40% uncertainty', fontsize=18)
#_ = axis[0,4].set_title('50% uncertainty', fontsize=18)
#_ = axis[2,0].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,1].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,2].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,3].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,4].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[1].set_xticklabels(axis[1].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[2].set_xticklabels(axis[2].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[3].set_xticklabels(axis[3].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[4].set_xticklabels(axis[4].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_yticklabels(np.around(axis[0].get_yticks() * 100, decimals=0),fontsize=16)
#_ = axis[1,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = axis[2,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = fig.tight_layout()
_ = fig.savefig('../Figures/InaccurStHeteroCampaigns_4DynHeteroResourcesSens2.png', bbox_inches='tight')

# %%
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.get_group(('HEFT', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.get_group(('HEFT', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.get_group(('HEFT', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.get_group(('HEFT', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.get_group(('HEFT', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc)] = [1024, value]

StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.groupby(by=['size'])

# %%
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.get_group(('L2FF', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.get_group(('L2FF', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.get_group(('L2FF', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.get_group(('L2FF', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.get_group(('L2FF', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc)] = [1024, value]

StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.groupby(by=['size'])

# %%
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.get_group(('GA-50', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.get_group(('GA-50', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.get_group(('GA-50', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.get_group(('GA-50', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc)] = [1024, value]
    
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc = pd.DataFrame(columns=['size','sens'])
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 4))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 4))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [4, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 8))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 8))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [8, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 16))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 16))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [16, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 32))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 32))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [32, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 64))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 64))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [64, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 128))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 128))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [128, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 256))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 256))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 256))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [256, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 512))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 512))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 512))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [512, value]
tmp = (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 1024))['makespan'] - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 1024))['makespan']) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.get_group(('GA-50', 1024))['makespan']
for value in tmp.values:
    StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.loc[len(StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc)] = [1024, value]

StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc = StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc = StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc = StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc = StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.groupby(by=['size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc = StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.groupby(by=['size'])

# %%
StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.describe()

# %%
HEFTy = np.array([(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'].values])

L2FFy = np.array([(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'].values])

GA50y = np.array([(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50')['makespan'].values,
                  (StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50')['makespan'].values - StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50')['makespan'].values) / StHeteroCampaigns_4StHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50')['makespan'].values])

z = np.array([[10],
     [20],
     [30],
     [40],
     [50]])

fig, axis = plt.subplots(ncols=3, nrows=1, figsize=(25,7.5), sharey=True, sharex=True)
#axis = fig.add_subplot(111, projection='3d')
_ = axis[0].errorbar(HEFTx[0], HEFTy[0], label='10% uncertainty', color=tableau20(2))
_ = axis[0].errorbar(HEFTx[1], HEFTy[1], label='20% uncertainty', color=tableau20(4))
_ = axis[0].errorbar(HEFTx[2], HEFTy[2], label='30% uncertainty', color=tableau20(6))
_ = axis[0].errorbar(HEFTx[3], HEFTy[3], label='40% uncertainty', color=tableau20(8))
_ = axis[0].errorbar(HEFTx[4], HEFTy[4], label='50% uncertainty', color=tableau20(10))

_ = axis[1].errorbar(GA50x[0], GA50y[0], label='10% uncertainty', color=tableau20(2))
_ = axis[1].errorbar(GA50x[1], GA50y[1], label='20% uncertainty', color=tableau20(4))
_ = axis[1].errorbar(GA50x[2], GA50y[2], label='30% uncertainty', color=tableau20(6))
_ = axis[1].errorbar(GA50x[3], GA50y[3], label='40% uncertainty', color=tableau20(8))
_ = axis[1].errorbar(GA50x[4], GA50y[4], label='50% uncertainty', color=tableau20(10))

_ = axis[2].errorbar(L2FFx[0], L2FFy[0], label='10% uncertainty', color=tableau20(2))
_ = axis[2].errorbar(L2FFx[1], L2FFy[1], label='20% uncertainty', color=tableau20(4))
_ = axis[2].errorbar(L2FFx[2], L2FFy[2], label='30% uncertainty', color=tableau20(6))
_ = axis[2].errorbar(L2FFx[3], L2FFy[3], label='40% uncertainty', color=tableau20(8))
_ = axis[2].errorbar(L2FFx[4], L2FFy[4], label='50% uncertainty', color=tableau20(10))
#_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
#_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis[0].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[1].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[2].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
#_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=10)
_ = axis[0].set_ylabel('Normalized Sensitivity', fontsize=16, labelpad=10)
_ = axis[1].legend(fontsize=16, loc=1, bbox_to_anchor=(.85, 0.85))
_ = axis[0].set_xscale('symlog', basex=2)
#_ = axis.set_xticks([4,8,16,32,64,128,256,1024])
#_ = axis.set_yticks([10,20,30,40,50])
_ = axis[0].grid('on')
_ = axis[1].grid('on')
_ = axis[2].grid('on')
_ = axis[0].set_title('HEFT', fontsize=18)
_ = axis[1].set_title('GA50', fontsize=18)
_ = axis[2].set_title('L2FF', fontsize=18)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[1].set_xticklabels(axis[1].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[2].set_xticklabels(axis[2].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_yticklabels(np.around(axis[0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = axis.set_zticklabels(np.around(axis.get_zticks().tolist(), decimals=2),fontsize=16)
#_ = fig.savefig('../Figures/InaccurStHeteroCampaigns_4DynHeteroResourcesSens.png', bbox_inches='tight')

fig, axis = plt.subplots(ncols=5, nrows=1, figsize=(35,5.5), sharey=True, sharex=True)
#axis = fig.add_subplot(111, projection='3d')
_ = axis[0].errorbar(HEFTx[0], StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_10perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[1].errorbar(HEFTx[1], StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_20perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[2].errorbar(HEFTx[2], StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_30perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[3].errorbar(HEFTx[3], StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_40perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[4].errorbar(HEFTx[4], StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_sens_50perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')

_ = axis[0].errorbar(GA50x[0], StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_sens_10perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[1].errorbar(GA50x[1], StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_sens_20perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[2].errorbar(GA50x[2], StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_sens_30perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[3].errorbar(GA50x[3], StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_sens_40perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[4].errorbar(GA50x[4], StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_sens_50perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')

_ = axis[0].errorbar(L2FFx[0], StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_10perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[1].errorbar(L2FFx[1], StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_20perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[2].errorbar(L2FFx[2], StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_30perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[3].errorbar(L2FFx[3], StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_40perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[4].errorbar(L2FFx[4], StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.mean().values, yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_sens_50perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
#_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
#_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis[0].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[1].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[2].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[3].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis[4].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
#_ = axis[2,3].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
#_ = axis[2,4].set_xlabel('Number of workflows', fontsize=16, labelpad=12)
#_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=10)
#_ = axis[0,0].set_ylabel('HEFT Normalized Sensitivity', fontsize=16, labelpad=10)
#_ = axis[1,0].set_ylabel('GA50 Normalized Sensitivity', fontsize=16, labelpad=10)
_ = axis[0].set_ylabel('Sensitivity in percentage', fontsize=16, labelpad=10)
_ = axis[2].legend(fontsize=16, loc='lower center', ncol=3, bbox_to_anchor=(.5,-.35))
_ = axis[0].set_xscale('symlog', basex=2)
#_ = axis.set_xticks([4,8,16,32,64,128,256,1024])
#_ = axis.set_yticks([10,20,30,40,50])
_ = axis[0].grid('on')
#_ = axis[0,1].grid('on')
#_ = axis[0,2].grid('on')
#_ = axis[0,3].grid('on')
#_ = axis[0,4].grid('on')

#_ = axis[1,0].grid('on')
#_ = axis[1,1].grid('on')
#_ = axis[1,2].grid('on')
#_ = axis[1,3].grid('on')
#_ = axis[1,4].grid('on')

#_ = axis[2,0].grid('on')
#_ = axis[2,1].grid('on')
#_ = axis[2,2].grid('on')
#_ = axis[2,3].grid('on')
#_ = axis[2,4].grid('on')
_ = axis[1].grid('on')
_ = axis[2].grid('on')
_ = axis[3].grid('on')
_ = axis[4].grid('on')
_ = axis[0].set_title('10% uncertainty', fontsize=18)
_ = axis[1].set_title('20% uncertainty', fontsize=18)
_ = axis[2].set_title('30% uncertainty', fontsize=18)
_ = axis[3].set_title('40% uncertainty', fontsize=18)
_ = axis[4].set_title('50% uncertainty', fontsize=18)
#_ = axis[0,3].set_title('40% uncertainty', fontsize=18)
#_ = axis[0,4].set_title('50% uncertainty', fontsize=18)
#_ = axis[2,0].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,1].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,2].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,3].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,4].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[1].set_xticklabels(axis[1].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[2].set_xticklabels(axis[2].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[3].set_xticklabels(axis[3].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[4].set_xticklabels(axis[4].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_yticklabels(np.around(axis[0].get_yticks() * 100, decimals=0),fontsize=16)
#_ = axis[1,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = axis[2,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = fig.tight_layout()
#_ = axis.set_zticklabels(np.around(axis.get_zticks().tolist(), decimals=2),fontsize=16)
#_ = fig.savefig('../Figures/InaccurStHeteroCampaigns_4DynHeteroResourcesSens.png', bbox_inches='tight')

# %%
print('HEFT:')
print(np.round(HEFTy, decimals=5))
print('GA-50:')
print(np.round(GA50y, decimals=5))
print('L2FF:')
print(np.round(L2FFy, decimals=5))

# %%
HEFTx = np.array([DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT').index.values.tolist()])

HEFTy = np.array([DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['mpn_snt_norm'].values.tolist()])

HEFTyStd = np.array([DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.std().xs('HEFT')['mpn_snt_norm'].values.tolist()])

L2FFx = np.array([DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF').index.values.tolist()])

L2FFy = np.array([DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF')['mpn_snt_norm'].values.tolist()])

L2FFyStd = np.array([DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.std().xs('L2FF')['mpn_snt_norm'].values.tolist()])

GA50x = np.array([DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50').index.values.tolist()])

GA50y = np.array([DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50')['mpn_snt_norm'].values.tolist()])

GA50yStd = np.array([DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist(),
                     DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.std().xs('GA-50')['mpn_snt_norm'].values.tolist()])

z = np.array([[10],
     [20],
     [30],
     [40],
     [50]])

fig, axis = plt.subplots(ncols=5, nrows=1, figsize=(35,5.5), sharey=True, sharex=True)
#axis = fig.add_subplot(111, projection='3d')
_ = axis[0].errorbar(HEFTx[0], HEFTy[0], yerr=HEFTyStd[0] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[1].errorbar(HEFTx[1], HEFTy[1], yerr=HEFTyStd[1] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[2].errorbar(HEFTx[2], HEFTy[2], yerr=HEFTyStd[2] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[3].errorbar(HEFTx[3], HEFTy[3], yerr=HEFTyStd[3] / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[4].errorbar(HEFTx[4], HEFTy[4], yerr=HEFTyStd[4] / 10, label='HEFT', color=tableau20(2), marker='s')

_ = axis[0].errorbar(GA50x[0], GA50y[0], yerr=GA50yStd[0] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[1].errorbar(GA50x[1], GA50y[1], yerr=GA50yStd[1] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[2].errorbar(GA50x[2], GA50y[2], yerr=GA50yStd[2] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[3].errorbar(GA50x[3], GA50y[3], yerr=GA50yStd[3] / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[4].errorbar(GA50x[4], GA50y[4], yerr=GA50yStd[4] / 10, label='GA-50', color=tableau20(8), marker='s')

_ = axis[0].errorbar(L2FFx[0], L2FFy[0], yerr=L2FFyStd[0] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[1].errorbar(L2FFx[1], L2FFy[1], yerr=L2FFyStd[1] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[2].errorbar(L2FFx[2], L2FFy[2], yerr=L2FFyStd[2] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[3].errorbar(L2FFx[3], L2FFy[3], yerr=L2FFyStd[3] / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[4].errorbar(L2FFx[4], L2FFy[4], yerr=L2FFyStd[4] / 10, label='L2FF', color=tableau20(10), marker='s')
#_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
#_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis[0].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[1].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[2].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[3].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[4].set_xlabel('Number of resources', fontsize=16, labelpad=12)
#_ = axis[2,3].set_xlabel('Number of resources', fontsize=16, labelpad=12)
#_ = axis[2,4].set_xlabel('Number of resources', fontsize=16, labelpad=12)
#_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=10)
_ = axis[0].set_ylabel('Sensitivity in percentage', fontsize=16, labelpad=10)
#_ = axis[1,0].set_ylabel('GA50 Normalized Sensitivity', fontsize=16, labelpad=10)
#_ = axis[2,0].set_ylabel('L2FF Normalized Sensitivity', fontsize=16, labelpad=10)
_ = axis[2].legend(fontsize=16, loc='lower center', ncol=3, bbox_to_anchor=(.5,-.35))
_ = axis[0].set_xscale('symlog', basex=2)
#_ = axis.set_xticks([4,8,16,32,64,128,256,1024])
#_ = axis.set_yticks([10,20,30,40,50])
#_ = axis[0,0].grid('on')
#_ = axis[0,1].grid('on')
#_ = axis[0,2].grid('on')
#_ = axis[0,3].grid('on')
#_ = axis[0,4].grid('on')

#_ = axis[1,0].grid('on')
#_ = axis[1,1].grid('on')
#_ = axis[1,2].grid('on')
#_ = axis[1,3].grid('on')
#_ = axis[1,4].grid('on')

#_ = axis[2,0].grid('on')
#_ = axis[2,1].grid('on')
#_ = axis[2,2].grid('on')
#_ = axis[2,3].grid('on')
#_ = axis[2,4].grid('on')
_ = axis[0].grid('on')
_ = axis[1].grid('on')
_ = axis[2].grid('on')
_ = axis[3].grid('on')
_ = axis[4].grid('on')
_ = axis[0].set_title('10% uncertainty', fontsize=18)
_ = axis[1].set_title('20% uncertainty', fontsize=18)
_ = axis[2].set_title('30% uncertainty', fontsize=18)
_ = axis[3].set_title('40% uncertainty', fontsize=18)
_ = axis[4].set_title('50% uncertainty', fontsize=18)
#_ = axis[0,3].set_title('40% uncertainty', fontsize=18)
#_ = axis[0,4].set_title('50% uncertainty', fontsize=18)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,1].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,2].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,3].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,4].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[1].set_xticklabels(axis[1].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[2].set_xticklabels(axis[2].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[3].set_xticklabels(axis[3].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[4].set_xticklabels(axis[4].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_yticklabels(np.around(axis[0].get_yticks() * 100, decimals=0),fontsize=16)
#_ = axis[1,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = axis[2,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = fig.tight_layout()
#_ = axis.set_zticklabels(np.around(axis.get_zticks().tolist(), decimals=2),fontsize=16)
_ = fig.savefig('../Figures/InaccurDynHeteroResources_StHeteroCampaignsSens2.png', bbox_inches='tight')

# %%
HEFTst = np.array([[0.00794, 0.01339, 0.01857, 0.02199, 0.02765, 0.02923],
                   [0.01822, 0.02247, 0.03822, 0.03914, 0.07303, 0.06887],
                   [0.02562, 0.03247, 0.06146, 0.07377, 0.11549, 0.11985],
                   [0.03262, 0.05844, 0.08637, 0.11719, 0.17611, 0.20866],
                   [0.04842, 0.07403, 0.10598, 0.15258, 0.2323,  0.26465]])


HEFTdiff = HEFTy - HEFTst

# %%
DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 4))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 4))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 8))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 8))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 16))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 16))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 32))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 32))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 64))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 64))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 128))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 128))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 4))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 4))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 8))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 8))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 16))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 16))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 32))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 32))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 64))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 64))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 128))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 128))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 4))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 4))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 8))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 8))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 16))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 16))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 32))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 32))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 64))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 64))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 128))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 128))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 4))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 4))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 8))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 8))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 16))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 16))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 32))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 32))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 64))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 64))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 128))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 128))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 4))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 4))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 8))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 8))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 16))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 16))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 32))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 32))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 64))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 64))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 128))['makespan'] - StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 128))['makespan']) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.get_group(('HEFT', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc = DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.groupby('size')
DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc = DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.groupby('size')
DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc = DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.groupby('size')
DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc = DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.groupby('size')
DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc = DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.groupby('size')

# %%
DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 4))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 4))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 8))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 8))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 16))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 16))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 32))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 32))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 64))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 64))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 128))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 128))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 4))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 4))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 8))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 8))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 16))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 16))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 32))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 32))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 64))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 64))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 128))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 128))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 4))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 4))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 8))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 8))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 16))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 16))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 32))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 32))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 64))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 64))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 128))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 128))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 4))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 4))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 8))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 8))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 16))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 16))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 32))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 32))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 64))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 64))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 128))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 128))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 4))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 4))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 8))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 8))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 16))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 16))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 32))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 32))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 64))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 64))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 128))['makespan'] - StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 128))['makespan']) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.get_group(('L2FF', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc = DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.groupby('size')
DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc = DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.groupby('size')
DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc = DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.groupby('size')
DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc = DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.groupby('size')
DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc = DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.groupby('size')

# %%
DynHeteroResources_StHeteroCampaignsGA50_sens_10perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 4))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 4))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_10perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 8))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 8))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_10perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 16))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 16))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_10perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 32))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 32))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_10perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 64))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 64))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_10perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 128))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 128))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_10perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsGA50_sens_20perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 4))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 4))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_20perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 8))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 8))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_20perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 16))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 16))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_20perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 32))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 32))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_20perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 64))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 64))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_20perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 128))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 128))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_20perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsGA50_sens_30perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 4))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 4))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_30perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 8))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 8))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_30perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 16))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 16))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_30perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 32))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 32))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_30perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 64))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 64))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_30perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 128))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 128))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_30perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsGA50_sens_40perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 4))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 4))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_40perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 8))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 8))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_40perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 16))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 16))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_40perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 32))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 32))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_40perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 64))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 64))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_40perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 128))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 128))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_40perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsGA50_sens_50perc = pd.DataFrame(columns=['size','sens'])
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 4))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 4))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 4))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_50perc)] = [4, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 8))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 8))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 8))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_50perc)] = [8, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 16))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 16))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 16))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_50perc)] = [16, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 32))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 32))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 32))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_50perc)] = [32, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 64))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 64))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 64))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_50perc)] = [64, value]
tmp = (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 128))['makespan'] - StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 128))['makespan']) / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.get_group(('GA-50', 128))['makespan']
for value in tmp.values:
    DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.loc[len(DynHeteroResources_StHeteroCampaignsGA50_sens_50perc)] = [128, value]

DynHeteroResources_StHeteroCampaignsGA50_sens_10perc = DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.groupby('size')
DynHeteroResources_StHeteroCampaignsGA50_sens_20perc = DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.groupby('size')
DynHeteroResources_StHeteroCampaignsGA50_sens_30perc = DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.groupby('size')
DynHeteroResources_StHeteroCampaignsGA50_sens_40perc = DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.groupby('size')
DynHeteroResources_StHeteroCampaignsGA50_sens_50perc = DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.groupby('size')

# %%
HEFTy = np.array([(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'].values - StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'].values) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'].values - StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'].values) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'].values - StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'].values) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'].values - StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'].values) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'].values - StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'].values) / StHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'].values])

L2FFy = np.array([(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'].values - StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'].values) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'].values - StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'].values) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'].values - StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'].values) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'].values - StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'].values) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'].values - StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'].values) / StHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'].values])

GA50y = np.array([(DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50')['makespan'].values - StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50')['makespan'].values) / StHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50')['makespan'].values - StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50')['makespan'].values) / StHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50')['makespan'].values - StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50')['makespan'].values) / StHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50')['makespan'].values - StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50')['makespan'].values) / StHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50')['makespan'].values,
                  (DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50')['makespan'].values - StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50')['makespan'].values) / StHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50')['makespan'].values])

z = np.array([[10],
     [20],
     [30],
     [40],
     [50]])

fig, axis = plt.subplots(ncols=3, nrows=1, figsize=(25,7.5), sharey=True, sharex=True)
#axis = fig.add_subplot(111, projection='3d')
_ = axis[0].errorbar(HEFTx[0], HEFTy[0], label='10% uncertainty', color=tableau20(2))
_ = axis[0].errorbar(HEFTx[1], HEFTy[1], label='20% uncertainty', color=tableau20(4))
_ = axis[0].errorbar(HEFTx[2], HEFTy[2], label='30% uncertainty', color=tableau20(6))
_ = axis[0].errorbar(HEFTx[3], HEFTy[3], label='40% uncertainty', color=tableau20(8))
_ = axis[0].errorbar(HEFTx[4], HEFTy[4], label='50% uncertainty', color=tableau20(10))

_ = axis[1].errorbar(GA50x[0], GA50y[0], label='10% uncertainty', color=tableau20(2))
_ = axis[1].errorbar(GA50x[1], GA50y[1], label='20% uncertainty', color=tableau20(4))
_ = axis[1].errorbar(GA50x[2], GA50y[2], label='30% uncertainty', color=tableau20(6))
_ = axis[1].errorbar(GA50x[3], GA50y[3], label='40% uncertainty', color=tableau20(8))
_ = axis[1].errorbar(GA50x[4], GA50y[4], label='50% uncertainty', color=tableau20(10))

_ = axis[2].errorbar(L2FFx[0], L2FFy[0], label='10% uncertainty', color=tableau20(2))
_ = axis[2].errorbar(L2FFx[1], L2FFy[1], label='20% uncertainty', color=tableau20(4))
_ = axis[2].errorbar(L2FFx[2], L2FFy[2], label='30% uncertainty', color=tableau20(6))
_ = axis[2].errorbar(L2FFx[3], L2FFy[3], label='40% uncertainty', color=tableau20(8))
_ = axis[2].errorbar(L2FFx[4], L2FFy[4], label='50% uncertainty', color=tableau20(10))
#_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
#_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis[0].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[1].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[2].set_xlabel('Number of resources', fontsize=16, labelpad=12)
#_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=10)
_ = axis[0].set_ylabel('Normalized Sensitivity', fontsize=16, labelpad=10)
_ = axis[1].legend(fontsize=16, loc=1, bbox_to_anchor=(.85, 0.85))
_ = axis[0].set_xscale('symlog', basex=2)
_ = axis[0].set_ylim([-0.01,0.04])
#_ = axis.set_xticks([4,8,16,32,64,128,256,1024])
#_ = axis.set_yticks([10,20,30,40,50])
_ = axis[0].grid('on')
_ = axis[1].grid('on')
_ = axis[2].grid('on')
_ = axis[0].set_title('HEFT', fontsize=18)
_ = axis[1].set_title('GA50', fontsize=18)
_ = axis[2].set_title('L2FF', fontsize=18)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[1].set_xticklabels(axis[1].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[2].set_xticklabels(axis[2].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_yticklabels(np.around(axis[0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = axis.set_zticklabels(np.around(axis.get_zticks().tolist(), decimals=2),fontsize=16)


fig, axis = plt.subplots(ncols=5, nrows=1, figsize=(35,5.5), sharey=True, sharex=True)
#axis = fig.add_subplot(111, projection='3d')
_ = axis[0].errorbar(HEFTx[0], DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsHEFT_sens_10perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[1].errorbar(HEFTx[1], DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsHEFT_sens_20perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[2].errorbar(HEFTx[2], DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsHEFT_sens_30perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[3].errorbar(HEFTx[3], DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsHEFT_sens_40perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')
_ = axis[4].errorbar(HEFTx[4], DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsHEFT_sens_50perc.std().values / 10, label='HEFT', color=tableau20(2), marker='s')

_ = axis[0].errorbar(HEFTx[0], HEFTdiff[0], marker='^')
_ = axis[1].errorbar(HEFTx[1], HEFTdiff[1], marker='^')
_ = axis[2].errorbar(HEFTx[2], HEFTdiff[2], marker='^')
_ = axis[3].errorbar(HEFTx[3], HEFTdiff[3], marker='^')
_ = axis[4].errorbar(HEFTx[4], HEFTdiff[4], marker='^')

_ = axis[0].errorbar(GA50x[0], DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsGA50_sens_10perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[1].errorbar(GA50x[1], DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsGA50_sens_20perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[2].errorbar(GA50x[2], DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsGA50_sens_30perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[3].errorbar(GA50x[3], DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsGA50_sens_40perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')
_ = axis[4].errorbar(GA50x[4], DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsGA50_sens_50perc.std().values / 10, label='GA-50', color=tableau20(8), marker='s')

_ = axis[0].errorbar(L2FFx[0], DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsL2FF_sens_10perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[1].errorbar(L2FFx[1], DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsL2FF_sens_20perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[2].errorbar(L2FFx[2], DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsL2FF_sens_30perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[3].errorbar(L2FFx[3], DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsL2FF_sens_40perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
_ = axis[4].errorbar(L2FFx[4], DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.mean().values, yerr=DynHeteroResources_StHeteroCampaignsL2FF_sens_50perc.std().values / 10, label='L2FF', color=tableau20(10), marker='s')
#_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
#_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis[0].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[1].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[2].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[3].set_xlabel('Number of resources', fontsize=16, labelpad=12)
_ = axis[4].set_xlabel('Number of resources', fontsize=16, labelpad=12)
#_ = axis[2,3].set_xlabel('Number of resources', fontsize=16, labelpad=12)
#_ = axis[2,4].set_xlabel('Number of resources', fontsize=16, labelpad=12)
#_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=10)
_ = axis[0].set_ylabel('Sensitivity in percentage', fontsize=16, labelpad=10)
#_ = axis[1,0].set_ylabel('GA50 Normalized Sensitivity', fontsize=16, labelpad=10)
#_ = axis[2,0].set_ylabel('L2FF Normalized Sensitivity', fontsize=16, labelpad=10)
_ = axis[2].legend(fontsize=16, loc='lower center', ncol=3, bbox_to_anchor=(.5,-.35))
_ = axis[0].set_xscale('symlog', basex=2)
#_ = axis.set_xticks([4,8,16,32,64,128,256,1024])
#_ = axis.set_yticks([10,20,30,40,50])
#_ = axis[0,0].grid('on')
#_ = axis[0,1].grid('on')
#_ = axis[0,2].grid('on')
#_ = axis[0,3].grid('on')
#_ = axis[0,4].grid('on')

#_ = axis[1,0].grid('on')
#_ = axis[1,1].grid('on')
#_ = axis[1,2].grid('on')
#_ = axis[1,3].grid('on')
#_ = axis[1,4].grid('on')

#_ = axis[2,0].grid('on')
#_ = axis[2,1].grid('on')
#_ = axis[2,2].grid('on')
#_ = axis[2,3].grid('on')
#_ = axis[2,4].grid('on')
_ = axis[0].grid('on')
_ = axis[1].grid('on')
_ = axis[2].grid('on')
_ = axis[3].grid('on')
_ = axis[4].grid('on')
_ = axis[0].set_title('10% uncertainty', fontsize=18)
_ = axis[1].set_title('20% uncertainty', fontsize=18)
_ = axis[2].set_title('30% uncertainty', fontsize=18)
_ = axis[3].set_title('40% uncertainty', fontsize=18)
_ = axis[4].set_title('50% uncertainty', fontsize=18)
#_ = axis[0,3].set_title('40% uncertainty', fontsize=18)
#_ = axis[0,4].set_title('50% uncertainty', fontsize=18)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,1].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,2].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,3].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
#_ = axis[2,4].set_xticklabels(axis[0,0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_xticklabels(axis[0].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[1].set_xticklabels(axis[1].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[2].set_xticklabels(axis[2].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[3].set_xticklabels(axis[3].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[4].set_xticklabels(axis[4].get_xticks().astype('int').tolist(),fontsize=16)
_ = axis[0].set_yticklabels(np.around(axis[0].get_yticks() * 100, decimals=0),fontsize=16)
#_ = axis[1,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = axis[2,0].set_yticklabels(np.around(axis[0,0].get_yticks().tolist(), decimals=2),fontsize=16)
#_ = fig.tight_layout()
#_ = axis.set_zticklabels(np.around(axis.get_zticks().tolist(), decimals=2),fontsize=16)
#_ = fig.savefig('../Figures/InaccurDynHeteroResources_StHeteroCampaignsSens.png', bbox_inches='tight')

# %%
HEFTy[4,1]

# %%
print('HEFT:')
print(np.round(HEFTy, decimals=5))
print('GA-50:')
print(np.round(GA50y, decimals=5))
print('L2FF:')
print(np.round(L2FFy, decimals=5))

print(HEFTy[1,-1] / HEFTy[0,-1],HEFTy[2,-1] / HEFTy[0,-1], HEFTy[2,-1] / HEFTy[0,-1], HEFTy[3,-1] / HEFTy[0,-1], HEFTy[4,-1] / HEFTy[4,1])
print(GA50y[1,-1] / GA50y[0,-1],GA50y[2,-1] / GA50y[0,-1], GA50y[2,-1] / GA50y[0,-1], GA50y[3,-1] / GA50y[0,-1], GA50y[4,-1] / GA50y[0,-1])
print(L2FFy[1,-1] / L2FFy[0,-1],L2FFy[2,-1] / L2FFy[0,-1], L2FFy[2,-1] / L2FFy[0,-1], L2FFy[3,-1] / L2FFy[0,-1], L2FFy[4,-1] / L2FFy[0,-1])

# %%
HEFTx = np.array([StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index.values.tolist()])

HEFTy = np.array([StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['gain_norm'].values.tolist()])

L2FFx = np.array([StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.mean().xs('L2FF').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index.values.tolist()])

L2FFy = np.array([StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['gain_norm'].values.tolist()])

GA50x = np.array([StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.mean().xs('GA-50').index.values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index.values.tolist()])

GA50y = np.array([StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['gain_norm'].values.tolist()])
z = np.array([[10],
     [20],
     [30],
     [40],
     [50],
     [60],
     [70],
     [80],
     [90]])

fig = plt.figure(figsize=(15,7.5))
axis = fig.add_subplot(111, projection='3d')
_ = axis.plot_wireframe(HEFTx,z,HEFTy,label='HEFT', color=tableau20(2))
_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis.set_xlabel('Number of workflows', fontsize=16, labelpad=12)
_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=10)
_ = axis.set_zlabel('Normalized Performance Gain', fontsize=16, labelpad=10)
_ = axis.legend(fontsize=16, loc=1, bbox_to_anchor=(.85, 0.85))
#_ = axis.set_xticks([4,8,16,32,64,128,256,1024])
_ = axis.set_yticks([10,20,30,40,50,60,70,80,90])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=16)
_ = axis.set_yticklabels(axis.get_yticks().tolist(),fontsize=16)
_ = axis.set_zticklabels(np.around(axis.get_zticks().tolist(), decimals=2),fontsize=16)
_ = fig.savefig('../Figures/InaccurStHeteroCampaigns_4DynHeteroResourcesGain.png', bbox_inches='tight')

# %%
HEFTx = np.array([DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index.values.tolist()])

HEFTy = np.array([DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['gain_norm'].values.tolist()])

L2FFx = np.array([DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.mean().xs('L2FF').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index.values.tolist()])

L2FFy = np.array([DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.mean().xs('L2FF')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['gain_norm'].values.tolist()])

GA50x = np.array([DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.mean().xs('GA-50').index.values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index.values.tolist()])

GA50y = np.array([DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.mean().xs('GA-50')['gain_norm'].values.tolist(),
                  DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['gain_norm'].values.tolist()])
z = np.array([[10],
     [20],
     [30],
     [40],
     [50],
     [60],
     [70],
     [80],
     [90]])

fig = plt.figure(figsize=(15,7.5))
axis = fig.add_subplot(111, projection='3d')
_ = axis.plot_wireframe(HEFTx,z,HEFTy,label='HEFT', color=tableau20(2))
_ = axis.plot_wireframe(GA50x,z,GA50y, color=tableau20(8), label='GA-50')
_ = axis.plot_wireframe(L2FFx,z,L2FFy, color=tableau20(10),label='L2FF')
_ = axis.set_xlabel('Number of resources', fontsize=16, labelpad=14)
_ = axis.set_ylabel('Uncertainty in percentage', fontsize=16, labelpad=12)
_ = axis.set_zlabel('Normalized Performance Gain', fontsize=16, labelpad=12)
_ = axis.legend(fontsize=16, loc=2, bbox_to_anchor=(.25, 0.85))
_ = axis.set_xticks([4,8,16,32,64,128])
_ = axis.set_yticks([10,20,30,40,50,60,70,80,90])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=16)
_ = axis.set_yticklabels(axis.get_yticks().tolist(),fontsize=16)
_ = axis.set_zticklabels(np.around(axis.get_zticks().tolist(), decimals=2),fontsize=16)
_ = fig.savefig('../Figures/InaccurDynHeteroResources_StHeteroCampaignsGain.png', bbox_inches='tight')

# %%
norm_gain =(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['reactive']) / StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['expected']

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Gain in thousands seconds',fontsize=20)
_ = axis.plot(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,norm_gain, marker='s',label='HEFT', color=tableau20(2),linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['rect_snt'],yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.std().xs('GA-50')['rect_snt'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['rect_snt'],yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.std().xs('L2FF')['rect_snt'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
#_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of workflows', fontsize=22)
_ = fig.savefig('../Figures/InaccurStHomoCampaigns_4DynResourcesGain.png',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['rect_snt'],yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['rect_snt'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['rect_snt'],yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['rect_snt'],color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['rect_snt'],yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.std().xs('L2FF')['rect_snt'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Gain in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('symlog')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('float').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of resources', fontsize=22)
_ = fig.savefig('../Figures/InaccurHeteroResources_StHomoCampaignsGain.png', bbox_inches='tight')
