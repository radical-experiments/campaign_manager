# %%
from matplotlib import pyplot as plt
from matplotlib import cm
import pandas as pd
from pprint import pprint
from random import randint
import numpy as np
#import matplotlib as mpl
#mpl.rcParams['text.usetex'] = True
#mpl.rcParams['text.latex.unicode'] = True

blues = cm.get_cmap(plt.get_cmap('Blues'))
greens = cm.get_cmap(plt.get_cmap('Greens'))
reds = cm.get_cmap(plt.get_cmap('Reds'))
oranges = cm.get_cmap(plt.get_cmap('Oranges'))
purples = cm.get_cmap(plt.get_cmap('Purples'))
greys = cm.get_cmap(plt.get_cmap('Greys'))
set1 = cm.get_cmap(plt.get_cmap('Set1'))
tab20 = cm.get_cmap(plt.get_cmap('tab20'))


def tableau20(color):
    # Use coordinated colors. These are the "Tableau 20" colors as
    # RGB. Each pair is strong/light. For a theory of color
    tableau20 = [(31 , 119, 180), (174, 199, 232), # blue        [ 0,1 ]
                 (255, 127, 14 ), (255, 187, 120), # orange      [ 2,3 ]
                 (44 , 160, 44 ), (152, 223, 138), # green       [ 4,5 ]
                 (214, 39 , 40 ), (255, 152, 150), # red         [ 6,7 ]
                 (148, 103, 189), (197, 176, 213), # purple      [ 8,9 ]
                 (140, 86 , 75 ), (196, 156, 148), # brown       [10,11]
                 (227, 119, 194), (247, 182, 210), # pink        [12,13]
                 (188, 189, 34 ), (219, 219, 141), # yellow      [14,15]
                 (23 , 190, 207), (158, 218, 229), # cyan        [16,17]
                 (65 , 68 , 81 ), (96 , 99 , 106), # gray        [18,19]
                 (127, 127, 127), (143, 135, 130), # gray        [20,21]
                 (165, 172, 175), (199, 199, 199), # gray        [22,23]
                 (207, 207, 207)]                   # gray        [24]
    # Scale the RGB values to the [0, 1] range, which is the format
    # matplotlib accepts.
    r, g, b = tableau20[color]
    return (round(r/255.,1), round(g/255.,1), round(b/255.,1))

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p10perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p20perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p30perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p40perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p50perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p5perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p60perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p70perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p80perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc['reactive']
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc = pd.read_csv('../Data/heft/DynHeteroResources_StHeteroCampaignsHEFT_inaccur_p90perc.csv')
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['gain'] = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['makespan'] - DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p10perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p20perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p30perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p40perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p50perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p5perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p60perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p70perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p80perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc = pd.read_csv('../Data/heft/StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_p90perc.csv')
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc['reactive']

DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc = DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc = StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.groupby(by=['planner','size'])

# %%
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p10perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p20perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p30perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p40perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p50perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p5perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p60perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p70perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p80perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc['reactive']
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc = pd.read_csv('../Data/l2ff/DynHeteroResources_StHeteroCampaignsL2FF_inaccur_p90perc.csv')
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['gain'] = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['makespan'] - DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p10perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p20perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p30perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p40perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p50perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p5perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p60perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p70perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p80perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc = pd.read_csv('../Data/l2ff/StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_p90perc.csv')
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc['reactive']


DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc = DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc = StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.groupby(by=['planner','size'])

# %%
DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p10perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p20perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p30perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p40perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p50perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p5perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p60perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p70perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p80perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc = pd.read_csv('../Data/ga/perc_050/DynHeteroResources_StHeteroCampaignsGA50_inaccur_p90perc.csv')
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['gain'] = DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['makespan'] - DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc['reactive']
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p10perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p20perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p30perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p40perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p50perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p5perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p60perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p70perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p80perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.drop(['plan', 'time'], axis=1, inplace=True)
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc = pd.read_csv('../Data/ga/perc_050/StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_p90perc.csv')
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['gain'] = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['makespan'] - StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc['reactive']
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.drop(['plan', 'time'], axis=1, inplace=True)

DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.groupby(by=['planner','size'])
DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc = DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.groupby(by=['planner','size'])
StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc = StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.groupby(by=['planner','size'])

# %%
#StHeteroCampaigns_4St100HeteroResources = pd.read_csv('../Data/StHeteroCampaigns_4St100HeteroResources2.csv')
#StHeteroCampaigns_4St100HeteroResources = StHeteroCampaigns_4St100HeteroResources.groupby(by=['planner','size'])

# %%
fig,axis = plt.subplots(nrows=10,ncols=1,figsize=(15,90),sharex=True, sharey=True)

#_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
#_ = axis.errorbar(StHeteroCampaigns_4St100HeteroResources.mean().xs('RANDOM').index,StHeteroCampaigns_4St100HeteroResources.mean().xs('RANDOM')['makespan'], yerr=StHeteroCampaigns_4St100HeteroResources.std().xs('RANDOM')['makespan'], marker='s',label='RANDOM', linewidth=2)
_ = axis[0].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.std().xs('HEFT')['makespan'], marker='s',label='5%', linewidth=2)
_ = axis[1].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.std().xs('HEFT')['makespan'], marker='s',label='10%', linewidth=2)
_ = axis[2].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.std().xs('HEFT')['makespan'], marker='s',label='20%', linewidth=2)
_ = axis[3].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.std().xs('HEFT')['makespan'], marker='s',label='30%', linewidth=2)
_ = axis[4].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.std().xs('HEFT')['makespan'], marker='s',label='40%', linewidth=2)
_ = axis[5].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.std().xs('HEFT')['makespan'], marker='s',label='50%', linewidth=2)
_ = axis[6].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.std().xs('HEFT')['makespan'], marker='s',label='60%', linewidth=2)
_ = axis[7].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.std().xs('HEFT')['makespan'], marker='s',label='70%', linewidth=2)
_ = axis[8].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.std().xs('HEFT')['makespan'], marker='s',label='80%', linewidth=2)
_ = axis[9].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['makespan'], marker='s',label='90%', linewidth=2)
_ = axis[0].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.std().xs('HEFT')['reactive'], marker='s',label='5%', linewidth=2)
_ = axis[1].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.std().xs('HEFT')['reactive'], marker='s',label='10%', linewidth=2)
_ = axis[2].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.std().xs('HEFT')['reactive'], marker='s',label='20%', linewidth=2)
_ = axis[3].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.std().xs('HEFT')['reactive'], marker='s',label='30%', linewidth=2)
_ = axis[4].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.std().xs('HEFT')['reactive'], marker='s',label='40%', linewidth=2)
_ = axis[5].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.std().xs('HEFT')['reactive'], marker='s',label='50%', linewidth=2)
_ = axis[6].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.std().xs('HEFT')['reactive'], marker='s',label='60%', linewidth=2)
_ = axis[7].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.std().xs('HEFT')['reactive'], marker='s',label='70%', linewidth=2)
_ = axis[8].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.std().xs('HEFT')['reactive'], marker='s',label='80%', linewidth=2)
_ = axis[9].errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['reactive'], marker='s',label='90%', linewidth=2)
#_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
_ = axis[0].set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
#_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
#_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
#_ = axis.grid('on')
#_ = axis.legend(fontsize=20)
#_ = axis.set_title('HEFT Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.std().xs('HEFT')['makespan'], marker='s',label='5%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.std().xs('HEFT')['makespan'], marker='s',label='10%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.std().xs('HEFT')['makespan'], marker='s',label='20%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.std().xs('HEFT')['makespan'], marker='s',label='30%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.std().xs('HEFT')['makespan'], marker='s',label='40%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.std().xs('HEFT')['makespan'], marker='s',label='50%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.std().xs('HEFT')['makespan'], marker='s',label='60%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.std().xs('HEFT')['makespan'], marker='s',label='70%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.std().xs('HEFT')['makespan'], marker='s',label='80%',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.std().xs('HEFT')['makespan'], marker='s',label='90%',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
#_ = axis.set_title('HEFT Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_5perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_5perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 5% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_5perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_5perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 5% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_10perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_10perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 10% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_10perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_10perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 10% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_20perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_20perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 20% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_20perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_20perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 20% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_30perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_30perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 30% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_30perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_30perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 30% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_40perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_40perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 40% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_40perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_40perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 40% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_50perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_50perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 50% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_50perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_50perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 50% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_60perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_60perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 60% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_60perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_60perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 60% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_70perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_70perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 70% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_70perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_70perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 70% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_80perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_80perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 80% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('StHomoCampaigns_4VarHomoResources.pdf',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_80perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_80perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('Makespan comparison of heterogeneous campaigns\non dynamic heterogeneous resources with 80% initial information inaccuracy', fontsize=22)
#_ = fig.savefig('VarHomoResources_StHomoCampaigns.pdf', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['makespan'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.std().xs('HEFT')['reactive'], marker='s',label='HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.std().xs('GA-50')['reactive'], color=tableau20(9),marker='^',label='GA-50',linewidth=2)
#_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF')['reactive'], yerr=StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
#_ = axis.set_xscale('symlog', basex=2)
#_ = axis.set_yscale('log')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of workflows', fontsize=22)
_ = fig.savefig('../Figures/PinaccurStHomoCampaigns_4DynResources.png',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.std().xs('HEFT')['makespan'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.std().xs('GA-50')['makespan'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['makespan'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.std().xs('L2FF')['makespan'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.std().xs('HEFT')['reactive'], marker='s',label='Reactive HEFT', color=tableau20(3),linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.std().xs('GA-50')['reactive'], color=tableau20(9),marker='^',label='Reactive GA-50',linewidth=2)
#_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF')['reactive'], yerr=DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.std().xs('L2FF')['reactive'], color=tableau20(11),marker='^',label='Reactive L2FF',linewidth=2)
_ = axis.set_ylabel('Makespan in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('log')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('int').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of resources', fontsize=22)
_ = fig.savefig('../Figures/PinaccurHeteroResources_StHomoCampaigns.png', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Gain in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').index,-StHeteroCampaigns_4DynHeteroResourcesGA50_inaccur_90perc.mean().xs('GA-50').diff(axis=1)['reactive'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').index,-StHeteroCampaigns_4DynHeteroResourcesL2FF_inaccur_90perc.mean().xs('L2FF').diff(axis=1)['reactive'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_yscale('symlog')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('float').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of workflows', fontsize=22)
_ = fig.savefig('../Figures/PinaccurStHomoCampaigns_4DynResourcesGain.png',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='HEFT', color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').index,-DynHeteroResources_StHeteroCampaignsGA50_inaccur_90perc.mean().xs('GA-50').diff(axis=1)['reactive'], color=tableau20(8),marker='^',label='GA-50',linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').index,-DynHeteroResources_StHeteroCampaignsL2FF_inaccur_90perc.mean().xs('L2FF').diff(axis=1)['reactive'], color=tableau20(10),marker='^',label='L2FF',linewidth=2)
_ = axis.set_ylabel('Gain in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
_ = axis.set_yscale('symlog')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('float').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of resources', fontsize=22)
_ = fig.savefig('../Figures/PinaccurHeteroResources_StHomoCampaignsGain.png', bbox_inches='tight')

# %%
fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))

_ = axis.set_ylabel('Gain in thousands seconds',fontsize=20)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_5perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='5',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_10perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='10',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_20perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='20',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_30perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='30',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_40perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='40',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_50perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='50',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_60perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='60',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_70perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='70',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_80perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='80',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').index,-StHeteroCampaigns_4DynHeteroResourcesHEFT_inaccur_90perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='90',)# color=tableau20(2),linewidth=2)
_ = axis.set_xlabel('Number of workflows',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-50,1050])
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_yscale('symlog')
#_ = axis.set_xticks([0,200,400,600,800,1000])
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('float').tolist(),fontsize=18)
_ = axis.grid('on')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of workflows', fontsize=22)
#_ = fig.savefig('../Figures/PinaccurStHomoCampaigns_4DynResourcesGain.png',bbox_inches='tight')

fig,axis = plt.subplots(nrows=1,ncols=1,figsize=(15,7.5))
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_5perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='5',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_10perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='10',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_20perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='20',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_30perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='30',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_40perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='40',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_50perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='50',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_60perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='60',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_70perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='70',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_80perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='80',)# color=tableau20(2),linewidth=2)
_ = axis.errorbar(DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').index,-DynHeteroResources_StHeteroCampaignsHEFT_inaccur_90perc.mean().xs('HEFT').diff(axis=1)['reactive'], marker='s',label='90',)# color=tableau20(2),linewidth=2)
_ = axis.set_ylabel('Gain in thousands seconds',fontsize=20)
_ = axis.set_xlabel('Number of resources',fontsize=20)
#_ = axis.set_ylim([-50,20000])
#_ = axis.set_xlim([-10,130])
#_ = axis.set_xticks([0,20,40,60,80,100, 120])
#_ = axis.set_yscale('symlog')
_ = axis.set_xscale('symlog', basex=2)
_ = axis.set_xticklabels(axis.get_xticks().astype('int').tolist(),fontsize=18)
_ = axis.set_yticklabels((axis.get_yticks()/1000).astype('float').tolist(),fontsize=18)
_ = axis.grid('on', which='both')
_ = axis.legend(fontsize=20)
_ = axis.set_title('As a function of the number of resources', fontsize=22)
#_ = fig.savefig('../Figures/PinaccurHeteroResources_StHomoCampaignsGain.png', bbox_inches='tight')
